# %%
import pandas as pd

# %%
data = pd.read_csv('2021-2022 Football Player Stats.csv', sep=';',encoding='latin-1')

# %%
data.head()
# Out:
#    Rk             Player Nation Pos          Squad            Comp   Age  \
# 0   1         Max Aarons    ENG  DF   Norwich City  Premier League  22.0
# 1   2   Yunis Abdelhamid    MAR  DF          Reims         Ligue 1  34.0
# 2   3  Salis Abdul Samed    GHA  MF  Clermont Foot         Ligue 1  22.0
# 3   4    Laurent Abergel    FRA  MF        Lorient         Ligue 1  29.0
# 4   5        Charles Abi    FRA  FW  Saint-Étienne         Ligue 1  22.0
#
#    Born  MP  Starts  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  AerWon  \
# 0  2000  34      32  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53    0.47
# 1  1987  34      34  ...  0.00  0.06  1.39    0.0   0.03  0.00   6.77    2.02
# 2  2000  31      29  ...  0.00  0.36  1.24    0.0   0.00  0.00   8.76    0.88
# 3  1993  34      34  ...  0.03  0.79  2.23    0.0   0.00  0.00   8.87    0.43
# 4  2000   1       1  ...  0.00  2.00  0.00    0.0   0.00  0.00   4.00    2.00
#
#    AerLost  AerWon%
# 0     1.59     22.7
# ...

# %%
data.set_index('Rk',inplace=True)

# %%
data.head()
# Out:
#                Player Nation Pos          Squad            Comp   Age  Born  \
# Rk
# 1          Max Aarons    ENG  DF   Norwich City  Premier League  22.0  2000
# 2    Yunis Abdelhamid    MAR  DF          Reims         Ligue 1  34.0  1987
# 3   Salis Abdul Samed    GHA  MF  Clermont Foot         Ligue 1  22.0  2000
# 4     Laurent Abergel    FRA  MF        Lorient         Ligue 1  29.0  1993
# 5         Charles Abi    FRA  FW  Saint-Étienne         Ligue 1  22.0  2000
#
#     MP  Starts   Min  ...   Off   Crs  TklW  PKwon  PKcon    OG  Recov  \
# Rk                    ...
# 1   34      32  2881  ...  0.03  1.41  1.16    0.0   0.06  0.03   5.53
# 2   34      34  2983  ...  0.00  0.06  1.39    0.0   0.03  0.00   6.77
# 3   31      29  2462  ...  0.00  0.36  1.24    0.0   0.00  0.00   8.76
# 4   34      34  2956  ...  0.03  0.79  2.23    0.0   0.00  0.00   8.87
# 5    1       1    45  ...  0.00  2.00  0.00    0.0   0.00  0.00   4.00
#
#     AerWon  AerLost  AerWon%
# Rk
# ...

# %%
for i in data.columns:
    print(i,end =", ")
# Out:
# Player, Nation, Pos, Squad, Comp, Age, Born, MP, Starts, Min, 90s, Goals, Shots, SoT, SoT%, G/Sh, G/SoT, ShoDist, ShoFK, ShoPK, PKatt, PasTotCmp, PasTotAtt, PasTotCmp%, PasTotDist, PasTotPrgDist, PasShoCmp, PasShoAtt, PasShoCmp%, PasMedCmp, PasMedAtt, PasMedCmp%, PasLonCmp, PasLonAtt, PasLonCmp%, Assists, PasAss, Pas3rd, PPA, CrsPA, PasProg, PasAtt, PasLive, PasDead, PasFK, TB, PasPress, Sw, PasCrs, CK, CkIn, CkOut, CkStr, PasGround, PasLow, PasHigh, PaswLeft, PaswRight, PaswHead, TI, PaswOther, PasCmp, PasOff, PasOut, PasInt, PasBlocks, SCA, ScaPassLive, ScaPassDead, ScaDrib, ScaSh, ScaFld, ScaDef, GCA, GcaPassLive, GcaPassDead, GcaDrib, GcaSh, GcaFld, GcaDef, Tkl, TklWon, TklDef3rd, TklMid3rd, TklAtt3rd, TklDri, TklDriAtt, TklDri%, TklDriPast, Press, PresSucc, Press%, PresDef3rd, PresMid3rd, PresAtt3rd, Blocks, BlkSh, BlkShSv, BlkPass, Int, Tkl+Int, Clr, Err, Touches, TouDefPen, TouDef3rd, TouMid3rd, TouAtt3rd, TouAttPen, TouLive, DriSucc, DriAtt, DriSucc%, DriPast, DriMegs, Carrie
# ...

# %%
for i in data.dtypes:
    print(i,end =" ")
# Out:
# object object object object object float64 int64 int64 int64 int64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 float64 flo
# ...

# %%
ColumnDescriptions = open('Column_Descriptions.txt','r').read().splitlines()

# %%
ColumnDescriptions
# Out:
# ['Rk : Rank',
#  "Player : Player's name",
#  "Nation : Player's nation",
#  'Pos : Position',
#  'Squad : Squadâ€™s name',
#  'Comp : League that squat occupies',
#  "Age : Player's age",
#  'Born : Year of birth',
#  'MP : Matches played',
#  'Starts : Matches started',
#  'Min : Minutes played',
#  '90s : Minutes played divided by 90',
#  'Goals : Goals scored or allowed',
#  'Shots : Shots total (Does not include penalty kicks)',
#  'SoT : Shots on target (Does not include penalty kicks)',
#  'SoT% : Shots on target percentage (Does not include penalty kicks)',
#  'G/Sh : Goals per shot',
#  'G/SoT : Goals per shot on target (Does not include penalty kicks)',
#  'ShoDist : Average distance, in yards, from goal of all shots taken (Does not include penalty kicks)',
#  'ShoFK : Shots from free kicks',
#  'ShoPK : Penalty kicks made',
#  'PKatt : Penalty kicks attempted',
#  'PasTotCmp : Passes completed',
#  'PasTotAtt : Passes attempted',
# ...

# %%
pd.options.display.max_columns = None
data.describe()
# Out:
#                Age         Born           MP       Starts          Min  \
# count  2920.000000  2921.000000  2921.000000  2921.000000  2921.000000
# mean     26.092123  1994.725094    18.800068    13.749743  1234.756248
# std       4.641746    37.210426    11.619882    11.393763   977.941288
# min      16.000000     0.000000     1.000000     0.000000     1.000000
# 25%      23.000000  1992.000000     8.000000     3.000000   307.000000
# 50%      26.000000  1996.000000    20.000000    12.000000  1102.000000
# 75%      29.000000  1999.000000    29.000000    23.000000  2025.000000
# max      41.000000  2006.000000    38.000000    38.000000  3420.000000
#
#                90s        Goals        Shots          SoT         SoT%  \
# count  2921.000000  2921.000000  2921.000000  2921.000000  2921.000000
# mean     13.719069     0.111274     1.220431     0.391462    23.618179
# std      10.865255     0.233688     1.511266     0.784754    21.355425
# ...

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.columns[data.isna().any()]
# Out:
# Index(['Nation', 'Age'], dtype='object')

# %%
data[data['Nation'].isna()]
# Out:
#               Player Nation   Pos     Squad     Comp  Age  Born  MP  Starts  \
# Rk
# 1532  Javier Llabrés    NaN  FWMF  Mallorca  La Liga  NaN     0   5       1
#
#       Min  90s  Goals  Shots   SoT  SoT%  G/Sh  G/SoT  ShoDist  ShoFK  ShoPK  \
# Rk
# 1532  132  1.5    0.0   3.33  1.33  40.0   0.0    0.0     24.5    0.0    0.0
#
#       PKatt  PasTotCmp  PasTotAtt  PasTotCmp%  PasTotDist  PasTotPrgDist  \
# Rk
# 1532    0.0       29.3       42.0        69.8       528.7           88.0
#
#       PasShoCmp  PasShoAtt  PasShoCmp%  PasMedCmp  PasMedAtt  PasMedCmp%  \
# Rk
# 1532       15.3       18.7        82.1       10.7       15.3        69.6
#
#       PasLonCmp  PasLonAtt  PasLonCmp%  Assists  PasAss  Pas3rd   PPA  CrsPA  \
# Rk
# 1532       3.33       6.67        50.0      0.0    1.33    1.33  0.67    0.0
#
#       PasProg  PasAtt  PasLive  PasDead  PasFK   TB  PasPress    Sw  PasCrs  \
# Rk
# 1532     0.67    42.0     40.7     1.33    0.0  0.0      9.33  2.67    3.33
#
# ...

# %%
data[data['Age'].isna()]
# Out:
#               Player Nation   Pos     Squad     Comp  Age  Born  MP  Starts  \
# Rk
# 1532  Javier Llabrés    NaN  FWMF  Mallorca  La Liga  NaN     0   5       1
#
#       Min  90s  Goals  Shots   SoT  SoT%  G/Sh  G/SoT  ShoDist  ShoFK  ShoPK  \
# Rk
# 1532  132  1.5    0.0   3.33  1.33  40.0   0.0    0.0     24.5    0.0    0.0
#
#       PKatt  PasTotCmp  PasTotAtt  PasTotCmp%  PasTotDist  PasTotPrgDist  \
# Rk
# 1532    0.0       29.3       42.0        69.8       528.7           88.0
#
#       PasShoCmp  PasShoAtt  PasShoCmp%  PasMedCmp  PasMedAtt  PasMedCmp%  \
# Rk
# 1532       15.3       18.7        82.1       10.7       15.3        69.6
#
#       PasLonCmp  PasLonAtt  PasLonCmp%  Assists  PasAss  Pas3rd   PPA  CrsPA  \
# Rk
# 1532       3.33       6.67        50.0      0.0    1.33    1.33  0.67    0.0
#
#       PasProg  PasAtt  PasLive  PasDead  PasFK   TB  PasPress    Sw  PasCrs  \
# Rk
# 1532     0.67    42.0     40.7     1.33    0.0  0.0      9.33  2.67    3.33
#
# ...
